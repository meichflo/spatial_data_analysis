# %% [markdown]
# # Preparation of GWR - Data

# %% [markdown]
# ## Libraries and Settings

# %%
# Libraries
import os
import json
import folium
import requests
import numpy as np
import pandas as pd
import geopandas as gpd
from datetime import date

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")

print(os.getcwd())
# Out:
# /workspaces/spatial_data_analysis/05_Python_GWR_Data

# %% [markdown]
# ## Download GWR data
#
# Source: https://public.madd.bfs.admin.ch

# %%
# Download latest file for the Canton of Zurich
url = "https://public.madd.bfs.admin.ch/buildings_zh.geojson"
response = requests.get(url)

# Ensure response is valid
if response.status_code == 200:
    # Open file in write mode and write the response content
    with open('buildings_zh.geojson', 'wb') as file:
        file.write(response.content)
else:
    print(f"Failed to download file, status code: {response.status_code}")

# %% [markdown]
# ## Import latest GWR Data

# %%
# Load json file
with open('buildings_zh.geojson') as f:
    data = json.load(f)

# Flatten nested json data
df_orig = pd.json_normalize(data, record_path=['features'])
df_orig

# Remove prefix
df_orig.columns = df_orig.columns.str.replace('properties.', '')
df_orig.columns = df_orig.columns.str.replace('geometry.', '')

# Create copy
df = df_orig.copy()
df.head()
# Out:
#       type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0  Feature      1            1004              1040           1271
# 1  Feature     10            1004              1020           1110
# 2  Feature    100            1004              1020           1110
# 3  Feature   1000            1007              1030           1110
# 4  Feature  10000            1004              1030           1121
#
#    municipalityNumber    municipalityName canton   type  \
# 0                   2  Affoltern am Albis     ZH  Point
# 1                   2  Affoltern am Albis     ZH  Point
# 2                   2  Affoltern am Albis     ZH  Point
# 3                   2  Affoltern am Albis     ZH  Point
# 4                 291         Andelfingen     ZH  Point
#
#                   coordinates
# 0          [2676523, 1235843]
# 1  [2676440.038, 1235973.538]
# 2  [2676765.706, 1236101.658]
# 3  [2676644.881, 1236812.863]
# 4   [2693391.65, 1272255.267]

# %% [markdown]
# ## Separate Swiss LV95 coordinates

# %%
# Separate coordinates
df['x_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['x_coord']
df['y_coords'] = pd.DataFrame(df['coordinates'].tolist(), columns=['x_coord', 'y_coord'])['y_coord']

# Remove column 'coordinates'
df = df.drop(['coordinates'], axis=1)
df
# Out:
#            type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0       Feature      1            1004              1040           1271
# 1       Feature     10            1004              1020           1110
# 2       Feature    100            1004              1020           1110
# 3       Feature   1000            1007              1030           1110
# 4       Feature  10000            1004              1030           1121
# ...         ...    ...             ...               ...            ...
# 393211  Feature  99995            1004              1040              0
# 393212  Feature  99996            1004              1040              0
# 393213  Feature  99997            1004              1040              0
# 393214  Feature  99998            1004              1040              0
# 393215  Feature  99999            1007              1040              0
#
#         municipalityNumber    municipalityName canton   type     x_coords  \
# 0                        2  Affoltern am Albis     ZH  Point  2676523.000
# 1                        2  Affoltern am Albis     ZH  Point  2676440.038
# 2                        2  Affoltern am Albis     ZH  Point  2676765.706
# 3                        2  Affoltern am Albis     ZH  Point  2676644.881
# 4                      291         Andelfingen     ZH  Point  2693391.650
# ...                    ...                 ...    ...    ...          ...
# 393211                 198               Uster     ZH  Point  2696792.976
# 393212                 198               Uster     ZH  Point  2696718.474
# 393213                 198               Uster     ZH  Point  2696722.040
# 393214                 198               Uster     ZH  Point  2696727.666
# 393215                 198               Uster     ZH  Point  2696710.888
#
#            y_coords
# 0       1235843.000
# 1       1235973.538
# 2       1236101.658
# 3       1236812.863
# 4       1272255.267
# ...             ...
# 393211  1245085.637
# 393212  1245039.536
# 393213  1245043.472
# 393214  1245050.586
# 393215  1245059.793
#
# [393216 rows x 11 columns]

# %% [markdown]
# ## Create WGS84 coordinates

# %%
# Create geodataframe and calculate latitude and longitude
gdf = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df['x_coords'], df['y_coords']), crs="EPSG:2056")

# Convert the Swiss LV95 coordinates to lat & lon
gdf = gdf.to_crs(epsg=4326)

# Get Latitude and Longitude
df['latitude'] = gdf['geometry'].y
df['longitude'] = gdf['geometry'].x

# Show data
df
# Out:
#            type   egid  buildingStatus  buildingCategory  buildingClass  \
# 0       Feature      1            1004              1040           1271
# 1       Feature     10            1004              1020           1110
# 2       Feature    100            1004              1020           1110
# 3       Feature   1000            1007              1030           1110
# 4       Feature  10000            1004              1030           1121
# ...         ...    ...             ...               ...            ...
# 393211  Feature  99995            1004              1040              0
# 393212  Feature  99996            1004              1040              0
# 393213  Feature  99997            1004              1040              0
# 393214  Feature  99998            1004              1040              0
# 393215  Feature  99999            1007              1040              0
#
#         municipalityNumber    municipalityName canton   type     x_coords  \
# 0                        2  Affoltern am Albis     ZH  Point  2676523.000
# 1                        2  Affoltern am Albis     ZH  Point  2676440.038
# 2                        2  Affoltern am Albis     ZH  Point  2676765.706
# 3                        2  Affoltern am Albis     ZH  Point  2676644.881
# 4                      291         Andelfingen     ZH  Point  2693391.650
# ...                    ...                 ...    ...    ...          ...
# 393211                 198               Uster     ZH  Point  2696792.976
# 393212                 198               Uster     ZH  Point  2696718.474
# 393213                 198               Uster     ZH  Point  2696722.040
# 393214                 198               Uster     ZH  Point  2696727.666
# 393215                 198               Uster     ZH  Point  2696710.888
#
#            y_coords   latitude  longitude
# 0       1235843.000  47.269056   8.449859
# 1       1235973.538  47.270239   8.448785
# 2       1236101.658  47.271354   8.453110
# 3       1236812.863  47.277764   8.451635
# 4       1272255.267  47.594339   8.680355
# ...             ...        ...        ...
# 393211  1245085.637  47.349516   8.719673
# 393212  1245039.536  47.349113   8.718677
# 393213  1245043.472  47.349147   8.718725
# 393214  1245050.586  47.349211   8.718801
# 393215  1245059.793  47.349296   8.718581
#
# [393216 rows x 13 columns]

# %% [markdown]
# ## Plot subset of buildings

# %%
# Subset
df_sub = df.loc[df['municipalityName'] == 'Greifensee'].sample(100).dropna()
df_sub

# Create the map
m = folium.Map(location=[df_sub['latitude'].mean(), df_sub['longitude'].mean()], zoom_start=15)

# Add points to the map
for idx, row in df_sub.iterrows():
    folium.Marker(location=([row['latitude'], 
                            row['longitude']]),
                  popup=row['buildingCategory']).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_71fd8f7c6ae89e46f9ed62599fba6ef9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_71fd8f7c6ae89e46f9ed62599fba6ef9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_71fd8f7c6ae89e46f9ed62599fba6ef9 = L.map(
#                 &quot;map_71fd8f7c6ae89e46f9ed62599fba6ef9&quot;,
#                 {
#                     center: [47.366994062649965, 8.680710834160516],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 15,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_957dd2817edc2268bb58d2ab1a778292 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_957dd2817edc2268bb58d2ab1a778292.addTo(map_71fd8f7c6ae89e46f9ed62599fba6ef9);
#
#
#             var marker_6822641065ea9a963e493cba5c25503d = L.marker(
#                 [47.36936626878006, 8.678101457451987],
#                 {}
#             ).addTo(map_71fd8f7c6ae89e46f9ed62599fba6ef9);
#
#
#         var popup_41e4f35d3bb9e14e1f66eeae86224968 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7923145504beaf5a9ba3c5376e6be127 = $(`&lt;div id=&quot;html_7923145504beaf5a9ba3c5376e6be127&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_41e4f35d3bb9e14e1f66eeae86224968.setContent(html_7923145504beaf5a9ba3c5376e6be127);
#
#
#
#         marker_6822641065ea9a963e493cba5c25503d.bindPopup(popup_41e4f35d3bb9e14e1f66eeae86224968)
#         ;
#
#
#
#
#             var marker_2713fb0ebc220b8db6d486b62b3e1825 = L.marker(
#                 [47.372460222869854, 8.678114032820336],
#                 {}
#             ).addTo(map_71fd8f7c6ae89e46f9ed62599fba6ef9);
#
#
#         var popup_f0e2a3cd5603a8833aca5d62c19c4d9c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3d10c7e7946bdfc9ff72e862e546fb20 = $(`&lt;div id=&quot;html_3d10c7e7946bdfc9ff72e862e546fb20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_f0e2a3cd5603a8833aca5d62c19c4d9c.setContent(html_3d10c7e7946bdfc9ff72e862e546fb20);
#
#
#
#         marker_2713fb0ebc220b8db6d486b62b3e1825.bindPopup(popup_f0e2a3cd5603a8833aca5d62c19c4d9c)
#         ;
#
#
#
#
#             var marker_0a87ac9ce66a78859f45c3ff6ac1d4e8 = L.marker(
#                 [47.36433781726365, 8.680400405997347],
#                 {}
#             ).addTo(map_71fd8f7c6ae89e46f9ed62599fba6ef9);
#
#
#         var popup_23bbbbdb30729ae08ddb55915b94d8e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_3f6d695323ea4d15ffd75a4d86536104 = $(`&lt;div id=&quot;html_3f6d695323ea4d15ffd75a4d86536104&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1080&lt;/div&gt;`)[0];
#                 popup_23bbbbdb30729ae08ddb55915b94d8e1.setContent(html_3f6d695323ea4d15ffd75a4d86536104);
#
#
#
#         marker_0a87ac9ce66a78859f45c3ff6ac1d4e8.bindPopup(popup_23bbbbdb30729ae08ddb55915b94d8e1)
#         ;
#
#
#
#
#             var marker_7bc0c4b36789d94a5e84c8d8537c379a = L.marker(
#                 [47.36818365694577, 8.680597078108127],
#                 {}
#             ).addTo(map_71fd8f7c6ae89e46f9ed62599fba6ef9);
#
#
#         var popup_a8d053527e4722024282bf1b09490764 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_7a49ab4d3e6fbff68ab985369c16fdfa = $(`&lt;div id=&quot;html_7a49ab4d3e6fbff68ab985369c16fdfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_a8d053527e4722024282bf1b09490764.setContent(html_7a49ab4d3e6fbff68ab985369c16fdfa);
#
#
#
#         marker_7bc0c4b36789d94a5e84c8d8537c379a.bindPopup(popup_a8d053527e4722024282bf1b09490764)
#         ;
#
#
#
#
#             var marker_02222730148e5cab73f24a70681216d3 = L.marker(
#                 [47.3645073783865, 8.679470069011911],
#                 {}
#             ).addTo(map_71fd8f7c6ae89e46f9ed62599fba6ef9);
#
#
#         var popup_3257e55023a127ff0dd232bfdad2ecdb = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d5d8c447d92e3dd9114645e73ed21f66 = $(`&lt;div id=&quot;html_d5d8c447d92e3dd9114645e73ed21f66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;1020&lt;/div&gt;`)[0];
#                 popup_3257e55023a127ff0dd232bfdad2ecdb.setContent(html_d5d8c447d92e3dd9114645e73ed21f66);
#
#
#
#         marker_02222730148e5cab73f24a70681216d3.bindPopup(popup_3257e55023a127ff0dd232bfdad2ecdb)
#         ;
#
#
#
#
#             var marker_33290fd9ddfd9d7b9e256162c847594e = L.marker(
#                 [47.35780947657049, 8.691325788599933],

# %% [markdown]
# ### Jupyter notebook --footer info-- (please always provide this at the end of each notebook)

# %%
import os
import platform
import socket
from platform import python_version
from datetime import datetime

print('-----------------------------------')
print(os.name.upper())
print(platform.system(), '|', platform.release())
print('Datetime:', datetime.now().strftime("%Y-%m-%d %H:%M:%S"))
print('Python Version:', python_version())
print('-----------------------------------')
# Out:
# -----------------------------------
# POSIX
# Linux | 6.2.0-1019-azure
# Datetime: 2024-03-19 08:31:50
# Python Version: 3.10.13
# -----------------------------------
